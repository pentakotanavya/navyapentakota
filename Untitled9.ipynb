# %% [markdown]
# <a href="https://colab.research.google.com/github/pentakotanavya/navyapentakota/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

# %%
import pandas as pd
data = pd.read_json("/content/json.json")

# %%
print(data)
# Out:
#           name     id nametype               recclass      mass  fall  \
# 0       Aachen      1    Valid                     L5      21.0  Fell
# 1       Aarhus      2    Valid                     H6     720.0  Fell
# 2         Abee      6    Valid                    EH4  107000.0  Fell
# 3     Acapulco     10    Valid            Acapulcoite    1914.0  Fell
# 4      Achiras    370    Valid                     L6     780.0  Fell
# ..         ...    ...      ...                    ...       ...   ...
# 995   Tirupati  24009    Valid                     H6     230.0  Fell
# 996    Tissint  54823    Valid  Martian (shergottite)    7000.0  Fell
# 997      Tjabe  24011    Valid                     H6   20000.0  Fell
# 998   Tjerebon  24012    Valid                     L5   16500.0  Fell
# 999  Tomakovka  24019    Valid                    LL6     600.0  Fell
#
#                         year    reclat    reclong  \
# 0    1880-01-01T00:00:00.000  50.77500    6.08333
# ...

# %%
import pandas as pd
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#           name     id nametype               recclass      mass  fall  \
# 0       Aachen      1    Valid                     L5      21.0  Fell
# 1       Aarhus      2    Valid                     H6     720.0  Fell
# 2         Abee      6    Valid                    EH4  107000.0  Fell
# 3     Acapulco     10    Valid            Acapulcoite    1914.0  Fell
# 4      Achiras    370    Valid                     L6     780.0  Fell
# ..         ...    ...      ...                    ...       ...   ...
# 995   Tirupati  24009    Valid                     H6     230.0  Fell
# 996    Tissint  54823    Valid  Martian (shergottite)    7000.0  Fell
# 997      Tjabe  24011    Valid                     H6   20000.0  Fell
# 998   Tjerebon  24012    Valid                     L5   16500.0  Fell
# 999  Tomakovka  24019    Valid                    LL6     600.0  Fell
#
#                         year    reclat    reclong  \
# 0    1880-01-01T00:00:00.000  50.77500    6.08333
# ...

# %%
df.sample()
# Out:
#             name     id nametype recclass   mass  fall  \
# 893  Schenectady  23458    Valid       H5  283.3  Fell
#
#                         year    reclat   reclong  \
# 893  1968-01-01T00:00:00.000  42.86083 -73.95028
#
#                                            geolocation  \
# 893  {'type': 'Point', 'coordinates': [-73.95028, 4...
#
#      :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4
# 893                         47.0                       2142.0

# %%
df.describe(include = 'all').T
# Out:
#                               count unique  \
# name                           1000   1000
# id                           1000.0    NaN
# nametype                       1000      1
# recclass                       1000    118
# mass                          972.0    NaN
# fall                           1000      2
# year                            999    247
# reclat                        988.0    NaN
# reclong                       988.0    NaN
# geolocation                     988    986
# :@computed_region_cbhk_fwbd   133.0    NaN
# :@computed_region_nnqa_25f4   134.0    NaN
#
#                                                                            top  \
# name                                                                    Aachen
# id                                                                         NaN
# nametype                                                                 Valid
# recclass                                                                    L6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         1000 non-null   object
#  1   id                           1000 non-null   int64
#  2   nametype                     1000 non-null   object
#  3   recclass                     1000 non-null   object
#  4   mass                         972 non-null    float64
#  5   fall                         1000 non-null   object
#  6   year                         999 non-null    object
#  7   reclat                       988 non-null    float64
#  8   reclong                      988 non-null    float64
#  9   geolocation                  988 non-null    object
#  10  :@computed_region_cbhk_fwbd  133 non-null    float64
#  11  :@computed_region_nnqa_25f4  134 non-null    float64
# dtypes: float64(5), int64(1), object(6)
# ...

# %%
df = df.astype({'name':'string','nametype':'string','recclass':'string'})

# %%
df['id']=df['id'].astype('int')

# %%
df = df.astype({'mass':'float','reclat':'float','reclong':'float'})

# %%
df['year'] = df['year'].apply(pd.to_datetime, format='%M:%S', errors='coerce', utc = True)

# %%
import pandas as pd

objs = [df,pd.DataFrame(df['geolocation'].tolist()).iloc[:, :2]]
df2=pd.concat(objs,axis=1).drop('geolocation',axis=1)
print(df2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-3bb32537a2a2> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 objs = [df,pd.DataFrame(df['geolocation'].tolist()).iloc[:, :2]]
#       4 df2=pd.concat(objs,axis=1).drop('geolocation',axis=1)
#       5 print(df2)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     744                     if columns is not None:
#     745                         columns = ensure_index(columns)
# --> 746                     arrays, columns, index = nested_data_to_arrays(
#     747                         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     748                         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#
# ...

# %%
df['geolocation'].str.split(pat = None,n=-1,expand=False)
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 995   NaN
# 996   NaN
# 997   NaN
# 998   NaN
# 999   NaN
# Name: geolocation, Length: 1000, dtype: float64
